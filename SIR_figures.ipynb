# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import csv

# %% [markdown]
# # Fast Travel, High Beta_2

# %%
# Reading in some data:

data_path = "Data/SIR_Fast_high.csv"
fast_high = np.zeros((301,3))

with open(data_path) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
            fast_high[line_count] = row
            line_count += 1
    print(f'Processed {line_count} lines.')
    

fast_high = fast_high.transpose()
# Out:
# Processed 301 lines.

# %%
plt.figure(figsize =(8,6))

plt.plot(fast_high[0], fast_high[1], linewidth = 8, color = "b")
plt.plot(fast_high[0], fast_high[2], linewidth = 8, color = "r")

plt.ylim(0,0.9)
# axes label size
plt.tick_params(axis = "both", which = "major", labelsize = 24)
plt.xlabel(r"Transmission Intensity $\beta_1/\gamma$", fontsize = 24)
plt.ylabel(r"$S_\infty$, Location 1", fontsize = 24, rotation = 90)
plt.xticks([0,1,2,3], ["0","1","2","3"])
plt.yticks([0,100,200,300,400,500])#, ["0","1","2","3"])

# legend
plt.legend(["Time at Risk Model","Flux Model"], \
           loc = ("upper right"), fontsize = 24)

plt.tight_layout()

plt.savefig("Figures/SIR_Fast_high_patch1.pdf")

# %%
data_path = "Data/SIR_Fast_high_time_series.csv"
fast_high_ts = np.zeros((241,5))

with open(data_path) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
            fast_high_ts[line_count] = row
            line_count += 1
    print(f'Processed {line_count} lines.')
    

fast_high_ts = fast_high_ts.transpose()
# Out:
# Processed 241 lines.

# %%
plt.figure(figsize =(8,6))

plt.plot(fast_high_ts[0], fast_high_ts[1], linewidth = 8, color = "b")
plt.plot(fast_high_ts[0], fast_high_ts[2], linewidth = 8, color = "r")
#plt.plot(fast_high_ts[0], fast_high_ts[1], linewidth = 8, color = "b")

#plt.plot(fast_high_ts[0], fast_high_ts[3], linewidth = 8, color = "b")
#plt.plot(fast_high_ts[0], fast_high_ts[4], linewidth = 8, color = "r")

plt.xlim(0.50)
plt.ylim(0,0.9)
# axes label size
plt.tick_params(axis = "both", which = "major", labelsize = 24)
plt.xlabel(r"time $t$", fontsize = 24)
plt.ylabel(r"$S(t)$, Location 1", fontsize = 24, rotation = 90)
plt.xticks([0,10,20,30,40,50])

plt.yticks([0,100,200,300,400,500])#, ["0","1","2","3"])

# legend
plt.legend(["Time at Risk Model","Flux Model"], \
           loc = ("upper right"), fontsize = 24)

plt.tight_layout()

plt.savefig("Figures/SIR_Fast_high_patch1_ts.pdf")

# %% [markdown]
# # Fast Travel, Low Beta 2

# %%
# Reading in some data:

data_path = "Data/SIR_Fast_low.csv"
fast_low = np.zeros((301,3))

with open(data_path) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
            fast_low[line_count] = row
            line_count += 1
    print(f'Processed {line_count} lines.')
    

fast_low = fast_low.transpose()
# Out:
# Processed 301 lines.

# %%
plt.figure(figsize =(8,6))

plt.plot(fast_low[0], fast_low[1], linewidth = 8, color = "b")
plt.plot(fast_low[0], fast_low[2], linewidth = 8, color = "r")

plt.ylim(0,0.9)
# axes label size
plt.tick_params(axis = "both", which = "major", labelsize = 24)
plt.xlabel(r"$\beta_1/\gamma$", fontsize = 24)
plt.ylabel(r"$S_\infty$, Location 1", fontsize = 24, rotation = 90)
plt.xticks([0,1,2,3], ["0","1","2","3"])
plt.yticks([0,100,200,300,400,500])#, ["0","1","2","3"])

# legend
#plt.legend(["Time at Risk Model","Flux Model"], \
#           loc = ("lower left"), fontsize = 24)

plt.tight_layout()

plt.savefig("Figures/SIR_Fast_low_patch1.pdf")

# %%
data_path = "Data/SIR_Fast_low_time_series.csv"
fast_low_ts = np.zeros((241,5))

with open(data_path) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
            fast_low_ts[line_count] = row
            line_count += 1
    print(f'Processed {line_count} lines.')
    

fast_low_ts = fast_low_ts.transpose()
# Out:
# Processed 241 lines.

# %%
plt.figure(figsize =(8,6))

plt.plot(fast_low_ts[0], fast_low_ts[1], linewidth = 8, color = "b")
plt.plot(fast_low_ts[0], fast_low_ts[2], linewidth = 8, color = "r")


plt.xlim(0.50)
plt.ylim(0,0.9)
# axes label size
plt.tick_params(axis = "both", which = "major", labelsize = 24)
plt.xlabel(r"time $t$", fontsize = 24)
plt.ylabel(r"$S(t)$, Location 1", fontsize = 24, rotation = 90)
plt.xticks([0,10,20,30,40,50])

plt.yticks([0,100,200,300,400,500])#, ["0","1","2","3"])

# legend
plt.legend(["Time at Risk Model","Flux Model"], \
           loc = ("upper right"), fontsize = 24)

plt.tight_layout()

plt.savefig("Figures/SIR_Fast_low_patch1_ts.pdf")

# %% [markdown]
# # Slow Travel, High Beta 2

# %%
# Reading in some data:

data_path = "Data/SIR_Slow_high.csv"
slow_high = np.zeros((301,3))

with open(data_path) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
            slow_high[line_count] = row
            line_count += 1
    print(f'Processed {line_count} lines.')
    

slow_high = slow_high.transpose()
# Out:
# Processed 301 lines.

# %%
plt.figure(figsize =(8,6))

plt.plot(slow_high[0], slow_high[1], linewidth = 8, color = "b")
plt.plot(slow_high[0], slow_high[2], linewidth = 8, color = "r")

plt.ylim(0,0.9)
# axes label size
plt.tick_params(axis = "both", which = "major", labelsize = 24)
plt.xlabel(r"Transmission Intensity $\beta_1/\gamma$", fontsize = 24)
plt.ylabel(r"$S_\infty$, Location 1", fontsize = 24, rotation = 90)
plt.xticks([0,1,2,3], ["0","1","2","3"])
plt.yticks([0,100,200,300,400,500])#, ["0","1","2","3"])

# legend
#plt.legend(["Time at Risk Model","Flux Model"], \
#           loc = ("upper right"), fontsize = 24)

plt.tight_layout()

plt.savefig("Figures/SIR_Slow_high_patch1.pdf")

# %%
data_path = "Data/SIR_Slow_high_time_series.csv"
slow_high_ts = np.zeros((241,5))

with open(data_path) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
            slow_high_ts[line_count] = row
            line_count += 1
    print(f'Processed {line_count} lines.')
    
slow_high_ts = slow_high_ts.transpose()
# Out:
# Processed 241 lines.

# %%
plt.figure(figsize =(8,6))

plt.plot(slow_high_ts[0], slow_high_ts[1], linewidth = 8, color = "b")
plt.plot(slow_high_ts[0], slow_high_ts[2], linewidth = 8, color = "r")


plt.xlim(0.50)
plt.ylim(0,0.9)
# axes label size
plt.tick_params(axis = "both", which = "major", labelsize = 24)
plt.xlabel(r"time $t$", fontsize = 24)
plt.ylabel(r"$S(t)$, Location 1", fontsize = 24, rotation = 90)
plt.xticks([0,10,20,30,40,50])

plt.yticks([0,100,200,300,400,500])#, ["0","1","2","3"])

# legend
plt.legend(["Time at Risk Model","Flux Model"], \
           loc = ("upper right"), fontsize = 24)

plt.tight_layout()

plt.savefig("Figures/SIR_Slow_high_patch1_ts.pdf")

# %% [markdown]
# # Slow Travel, Low Beta 2

# %%
# Reading in some data:

data_path = "Data/SIR_Slow_low.csv"
slow_low = np.zeros((301,3))

with open(data_path) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
            slow_low[line_count] = row
            line_count += 1
    print(f'Processed {line_count} lines.')
    

slow_low = slow_low.transpose()
# Out:
# Processed 301 lines.

# %%
plt.figure(figsize =(8,6))

plt.plot(slow_low[0], slow_low[1], linewidth = 8, color = "b")
plt.plot(slow_low[0], slow_low[2], linewidth = 8, color = "r")

plt.ylim(0,0.9)
# axes label size
plt.tick_params(axis = "both", which = "major", labelsize = 24)
plt.xlabel(r"Transmission Intensity $\beta_1/\gamma$", fontsize = 24)
plt.ylabel(r"$S_\infty$, Location 1", fontsize = 24, rotation = 90)
plt.xticks([0,1,2,3], ["0","1","2","3"])
plt.yticks([0,100,200,300,400,500])#, ["0","1","2","3"])

# legend
#plt.legend(["Time at Risk Model","Flux Model"], \
#           loc = ("lower left"), fontsize = 24)

plt.tight_layout()

plt.savefig("Figures/SIR_Slow_low_patch1.pdf")

# %%
data_path = "Data/SIR_Slow_low_time_series.csv"
slow_low_ts = np.zeros((241,5))

with open(data_path) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
            slow_low_ts[line_count] = row
            line_count += 1
    print(f'Processed {line_count} lines.')
    
slow_low_ts = slow_low_ts.transpose()
# Out:
# Processed 241 lines.

# %%
plt.figure(figsize =(8,6))

plt.plot(slow_low_ts[0], slow_low_ts[1], linewidth = 8, color = "b")
plt.plot(slow_low_ts[0], slow_low_ts[2], linewidth = 8, color = "r")


plt.xlim(0.50)
plt.ylim(0,0.9)
# axes label size
plt.tick_params(axis = "both", which = "major", labelsize = 24)
plt.xlabel(r"time $t$", fontsize = 24)
plt.ylabel(r"$S(t)$, Location 1", fontsize = 24, rotation = 90)
plt.xticks([0,10,20,30,40,50])

plt.yticks([0,100,200,300,400,500])#, ["0","1","2","3"])

# legend
plt.legend(["Time at Risk Model","Flux Model"], \
           loc = ("upper right"), fontsize = 24)

plt.tight_layout()

plt.savefig("Figures/SIR_Slow_low_patch1_ts.pdf")
